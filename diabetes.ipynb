# %%
import pandas as pd

# %%
df= pd.read_csv('/content/diabetes_prediction_dataset (1).csv')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.shape
# Out:
# (100000, 9)

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()

# %%
encoder.fit_transform(df.loc[:,'gender'])
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
df.loc[:,'gender_new'] = encoder.fit_transform(df.loc[:,'gender'])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  gender_new
# 0          6.6                  140         0           0
# 1          6.6                   80         0           0
# 2          5.7                  158         0           1
# 3          5.0                  155         0           0
# 4          4.8                  155         0           1

# %%
df.loc[:,'gender_new'].value_counts()
# Out:
# gender_new
# 0    58552
# 1    41430
# 2       18
# Name: count, dtype: int64

# %%
df.loc[:,'smoking_history'] = encoder.fit_transform(df.loc[:,'smoking_history'])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1               4  25.19
# 1  Female  54.0             0              0               0  27.32
# 2    Male  28.0             0              0               4  27.32
# 3  Female  36.0             0              0               1  23.45
# 4    Male  76.0             1              1               1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  gender_new
# 0          6.6                  140         0           0
# 1          6.6                   80         0           0
# 2          5.7                  158         0           1
# 3          5.0                  155         0           0
# 4          4.8                  155         0           1

# %%
df.loc[:,'smoking_history'].value_counts()
# Out:
# smoking_history
# 0    35816
# 4    35095
# 3     9352
# 1     9286
# 5     6447
# 2     4004
# Name: count, dtype: int64

# %%
df.drop('gender_new', axis=1, inplace=True)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1               4  25.19
# 1      Female  54.0             0              0               0  27.32
# 2        Male  28.0             0              0               4  27.32
# 3      Female  36.0             0              0               1  23.45
# 4        Male  76.0             1              1               1  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0               0  27.32
# 99996  Female   2.0             0              0               0  17.37
# 99997    Male  66.0             0              0               3  27.83
# 99998  Female  24.0             0              0               4  35.42
# 99999  Female  57.0             0              0               1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.loc[:,'gender'] = encoder.fit_transform(df.loc[:,'gender'])

# %%
df
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0          0  80.0             0              1               4  25.19
# 1          0  54.0             0              0               0  27.32
# 2          1  28.0             0              0               4  27.32
# 3          0  36.0             0              0               1  23.45
# 4          1  76.0             1              1               1  20.14
# ...      ...   ...           ...            ...             ...    ...
# 99995      0  80.0             0              0               0  27.32
# 99996      0   2.0             0              0               0  17.37
# 99997      1  66.0             0              0               3  27.83
# 99998      0  24.0             0              0               4  35.42
# 99999      0  57.0             0              0               1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (100000, 9)

# %%
X = df.iloc[:,:-1]
X
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0          0  80.0             0              1               4  25.19
# 1          0  54.0             0              0               0  27.32
# 2          1  28.0             0              0               4  27.32
# 3          0  36.0             0              0               1  23.45
# 4          1  76.0             1              1               1  20.14
# ...      ...   ...           ...            ...             ...    ...
# 99995      0  80.0             0              0               0  27.32
# 99996      0   2.0             0              0               0  17.37
# 99997      1  66.0             0              0               3  27.83
# 99998      0  24.0             0              0               4  35.42
# 99999      0  57.0             0              0               1  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
y = df.iloc[:,-1]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=40)

# %%
X_train.shape
# Out:
# (80000, 8)

# %%
y_train.shape
# Out:
# (80000,)

# %%
X_test.shape
# Out:
# (20000, 8)

# %%
y_test.shape
# Out:
# (20000,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.95165
